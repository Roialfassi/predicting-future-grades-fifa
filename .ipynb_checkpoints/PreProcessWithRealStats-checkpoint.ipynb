# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
path_to_raw = "Dataset/Raw-Data"
output_folder = "Dataset/After-PreProcess"

# %% [markdown]
# Load Fifa Ratings

# %%
fifa_ratings =  pd.read_csv(r"Dataset\After-PreProcess\predict-by-rating\Combined_Data.csv",low_memory = False)

# %%
fifa_ratings = fifa_ratings.drop("Unnamed: 0", axis=1)

# %%
fifa_ratings
# Out:
#            ID             Name  Age  Overall  Potential  \
# 0      176580        L. Suárez   29       92         92
# 1      178518    R. Nainggolan   28       86         86
# 2      181872         A. Vidal   29       87         87
# 3      197445         D. Alaba   24       86         89
# 4      195864         P. Pogba   23       88         94
# ...       ...              ...  ...      ...        ...
# 68477  254562          A. Abaz   19       50         70
# 68478  262373  F. Chalupniczak   20       51         63
# 68479  263373        J. Searle   20       51         64
# 68480  259718      F. Gebhardt   19       52         66
# 68481  262846         �. Dobre   20       53         63
#
#                         Club      Value    Wage  International Reputation  \
# 0               FC Barcelona  107500000  250000                       5.0
# 1                       Roma   93000000  140000                       3.0
# 2          FC Bayern München   44500000  135000                       4.0
# 3          FC Bayern München  125500000  350000                       4.0
# 4          Manchester United   37000000   45000                       4.0
# ...                      ...        ...     ...                       ...
# 68477     FC St. Gallen 1879     120000     500                       1.0
# 68478          Sutton United     120000     800                       1.0
# 68479           Swansea City     120000    2000                       1.0
# 68480          FC Basel 1893     170000     650                       1.0
# 68481  FC Academica Clinceni     180000     550                       1.0
#
#        Weak Foot  ...  GKDiving GKHandling GKKicking GKPositioning GKReflexes  \
# 0            4.0  ...      27.0       25.0      31.0          33.0       37.0
# 1            3.0  ...      11.0       11.0      14.0           8.0       11.0
# 2            4.0  ...       4.0        2.0       4.0           2.0        4.0
# 3            4.0  ...       5.0        7.0      14.0          15.0        9.0
# 4            4.0  ...       5.0        6.0       2.0           4.0        3.0
# ...          ...  ...       ...        ...       ...           ...        ...
# 68477        2.0  ...      49.0       53.0      50.0          48.0       50.0
# 68478        2.0  ...      50.0       52.0      51.0          51.0       52.0
# 68479        3.0  ...      51.0       53.0      52.0          49.0       50.0
# 68480        3.0  ...      53.0       45.0      47.0          52.0       57.0
# 68481        2.0  ...      57.0       52.0      53.0          48.0       58.0
#
#        Best Position  version  Next_Overall         Next_Year_Club  \
# 0                 ST     2017          92.0           FC Barcelona
# 1                CDM     2017          86.0                   Roma
# 2                CDM     2017          86.0      FC Bayern München
# 3                 LB     2017          85.0      FC Bayern München
# 4                CAM     2017          88.0      Manchester United
# ...              ...      ...           ...                    ...
# 68477             GK     2022          50.0          FC Winterthur
# 68478             GK     2022          51.0          Sutton United
# 68479             GK     2022          51.0               Barnsley
# 68480             GK     2022          58.0          Hallescher FC
# 68481             GK     2022          55.0  FC Academica Clinceni
#
#        DefensiveAwareness
# 0                      50
# 1                      79
# 2                      85
# 3                      81
# 4                      72
# ...                   ...
# 68477                   7
# 68478                   9
# 68479                   7
# 68480                   6
# 68481                   5
#
# [68482 rows x 53 columns]
