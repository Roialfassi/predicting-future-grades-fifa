# %% [markdown]
# # Pre Process The Data

# %% [markdown]
# ## Table of Contents
#
# * [Add Labels](#Add-Labels)
# * [Combine All Datasets To 1](#Combine-All-Datasets-To-1)
# * [Drop Unused Columns](#Drop-Unused-Columns)
# * [Convert Wage to int](#Convert-Wage-to-int)
# * [Handling Missing Values](#Handling-Missing-Values)
# * [Split to Positions](#Split-to-Positions)
# * [FIFA23 - Prep](#FIFA23-Prep)
# * [Export](#Export)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
path_to_raw = "Dataset/Raw-Data"
output_folder = "Dataset/After-PreProcess"

# %%
f_2017 = pd.read_csv(path_to_raw+"/FIFA17_official_data.csv" ,low_memory = False)
f_2018 = pd.read_csv(path_to_raw+"/FIFA18_official_data.csv" ,low_memory = False)
f_2019 = pd.read_csv(path_to_raw+"/FIFA19_official_data.csv" ,low_memory = False)
f_2020 = pd.read_csv(path_to_raw+"/FIFA20_official_data.csv" ,low_memory = False)
f_2021 = pd.read_csv(path_to_raw+"/FIFA21_official_data.csv" ,low_memory = False)
f_2022 = pd.read_csv(path_to_raw+"/FIFA22_official_data.csv" ,low_memory = False)

# %%
f_2023 = pd.read_csv(path_to_raw+"/FIFA23_official_data.csv" ,low_memory = False)

# %%
f_2017["version"]= 2017
f_2018["version"]= 2018
f_2019["version"]= 2019
f_2020["version"]= 2020
f_2021["version"]= 2021
f_2022["version"]= 2022
f_2023["version"]= 2023

# %%
f_2017
# Out:
#            ID            Name  Age  \
# 0      176580       L. Suárez   29
# 1      178518   R. Nainggolan   28
# 2      181872        A. Vidal   29
# 3      197445        D. Alaba   24
# 4      195864        P. Pogba   23
# ...       ...             ...  ...
# 17555  233215        C. Addai   18
# 17556  232911     R. Kamiyama   31
# 17557  235387         B. Gaye   18
# 17558  237904   K. Olifirenko   18
# 17559  237463       A. Kelsey   16
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1      https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2      https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3      https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4      https://cdn.sofifa.com/players/195/864/17_60.png      France
# ...                                                 ...         ...
# 17555  https://cdn.sofifa.com/players/233/215/17_60.png       Ghana
# 17556  https://cdn.sofifa.com/players/232/911/17_60.png       Japan
# 17557  https://cdn.sofifa.com/players/235/387/17_60.png     Germany
# 17558  https://cdn.sofifa.com/players/237/904/17_60.png      Russia
# 17559  https://cdn.sofifa.com/players/237/463/17_60.png     England
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/uy.png       92         92
# 1          https://cdn.sofifa.com/flags/be.png       86         86
# 2          https://cdn.sofifa.com/flags/cl.png       87         87
# 3          https://cdn.sofifa.com/flags/at.png       86         89
# 4          https://cdn.sofifa.com/flags/fr.png       88         94
# ...                                        ...      ...        ...
# 17555      https://cdn.sofifa.com/flags/gh.png       54         72
# 17556      https://cdn.sofifa.com/flags/jp.png       57         57
# 17557      https://cdn.sofifa.com/flags/de.png       53         67
# 17558      https://cdn.sofifa.com/flags/ru.png       50         66
# 17559  https://cdn.sofifa.com/flags/gb-eng.png       46         63
#
#                         Club  \
# 0               FC Barcelona
# 1                       Roma
# 2          FC Bayern München
# 3          FC Bayern München
# 4          Manchester United
# ...                      ...
# 17555          Coventry City
# 17556         Avispa Fukuoka
# 17557  DSC Arminia Bielefeld
# 17558           FC Tom Tomsk
# 17559      Scunthorpe United
#
#                                               Club Logo  ... StandingTackle  \
# 0         https://cdn.sofifa.com/teams/241/light_30.png  ...           45.0
# 1          https://cdn.sofifa.com/teams/52/light_30.png  ...           85.0
# 2          https://cdn.sofifa.com/teams/21/light_30.png  ...           89.0
# 3          https://cdn.sofifa.com/teams/21/light_30.png  ...           83.0
# 4          https://cdn.sofifa.com/teams/11/light_30.png  ...           73.0
# ...                                                 ...  ...            ...
# 17555    https://cdn.sofifa.com/teams/1800/light_30.png  ...           13.0
# 17556  https://cdn.sofifa.com/teams/113186/light_30.png  ...           10.0
# 17557     https://cdn.sofifa.com/teams/159/light_30.png  ...           13.0
# 17558  https://cdn.sofifa.com/teams/110233/light_30.png  ...           13.0
# 17559    https://cdn.sofifa.com/teams/1949/light_30.png  ...           11.0
#
#       SlidingTackle  GKDiving GKHandling  GKKicking  GKPositioning  \
# 0              38.0      27.0       25.0       31.0           33.0
# 1              88.0      11.0       11.0       14.0            8.0
# 2              84.0       4.0        2.0        4.0            2.0
# 3              83.0       5.0        7.0       14.0           15.0
# 4              73.0       5.0        6.0        2.0            4.0
# ...             ...       ...        ...        ...            ...
# 17555          13.0      51.0       51.0       48.0           59.0
# 17556          11.0      59.0       46.0       41.0           62.0
# 17557          12.0      54.0       50.0       49.0           54.0
# 17558          13.0      47.0       59.0       52.0           44.0
# 17559          10.0      46.0       47.0       54.0           43.0
#
#        GKReflexes Best Position Best Overall Rating version
# 0            37.0            ST                88.0    2017
# 1            11.0           CDM                84.0    2017
# 2             4.0           CDM                85.0    2017
# 3             9.0            LB                84.0    2017
# 4             3.0           CAM                85.0    2017
# ...           ...           ...                 ...     ...
# 17555        60.0            GK                53.0    2017
# 17556        59.0            GK                56.0    2017
# 17557        58.0            GK                52.0    2017
# 17558        49.0            GK                49.0    2017
# 17559        48.0            GK                45.0    2017
#
# [17560 rows x 64 columns]

# %%
def addNextGradeToDf (prev_year ,  next_year):
    grade_dict = dict(zip(next_year['ID'], next_year['Overall']))
    prev_year['Next_Overall'] = prev_year['ID'].map(grade_dict)
    return prev_year

# %%
def addNextClubToDf (prev_year ,  next_year):
    grade_dict = dict(zip(next_year['ID'], next_year['Club']))
    prev_year['Next_Year_Club'] = prev_year['ID'].map(grade_dict)
    return prev_year

# %% [markdown]
# ## Add Labels

# %%
addNextGradeToDf(f_2017, f_2018)
addNextClubToDf(f_2017, f_2018)
# Out:
#            ID            Name  Age  \
# 0      176580       L. Suárez   29
# 1      178518   R. Nainggolan   28
# 2      181872        A. Vidal   29
# 3      197445        D. Alaba   24
# 4      195864        P. Pogba   23
# ...       ...             ...  ...
# 17555  233215        C. Addai   18
# 17556  232911     R. Kamiyama   31
# 17557  235387         B. Gaye   18
# 17558  237904   K. Olifirenko   18
# 17559  237463       A. Kelsey   16
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1      https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2      https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3      https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4      https://cdn.sofifa.com/players/195/864/17_60.png      France
# ...                                                 ...         ...
# 17555  https://cdn.sofifa.com/players/233/215/17_60.png       Ghana
# 17556  https://cdn.sofifa.com/players/232/911/17_60.png       Japan
# 17557  https://cdn.sofifa.com/players/235/387/17_60.png     Germany
# 17558  https://cdn.sofifa.com/players/237/904/17_60.png      Russia
# 17559  https://cdn.sofifa.com/players/237/463/17_60.png     England
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/uy.png       92         92
# 1          https://cdn.sofifa.com/flags/be.png       86         86
# 2          https://cdn.sofifa.com/flags/cl.png       87         87
# 3          https://cdn.sofifa.com/flags/at.png       86         89
# 4          https://cdn.sofifa.com/flags/fr.png       88         94
# ...                                        ...      ...        ...
# 17555      https://cdn.sofifa.com/flags/gh.png       54         72
# 17556      https://cdn.sofifa.com/flags/jp.png       57         57
# 17557      https://cdn.sofifa.com/flags/de.png       53         67
# 17558      https://cdn.sofifa.com/flags/ru.png       50         66
# 17559  https://cdn.sofifa.com/flags/gb-eng.png       46         63
#
#                         Club  \
# 0               FC Barcelona
# 1                       Roma
# 2          FC Bayern München
# 3          FC Bayern München
# 4          Manchester United
# ...                      ...
# 17555          Coventry City
# 17556         Avispa Fukuoka
# 17557  DSC Arminia Bielefeld
# 17558           FC Tom Tomsk
# 17559      Scunthorpe United
#
#                                               Club Logo  ... GKDiving  \
# 0         https://cdn.sofifa.com/teams/241/light_30.png  ...     27.0
# 1          https://cdn.sofifa.com/teams/52/light_30.png  ...     11.0
# 2          https://cdn.sofifa.com/teams/21/light_30.png  ...      4.0
# 3          https://cdn.sofifa.com/teams/21/light_30.png  ...      5.0
# 4          https://cdn.sofifa.com/teams/11/light_30.png  ...      5.0
# ...                                                 ...  ...      ...
# 17555    https://cdn.sofifa.com/teams/1800/light_30.png  ...     51.0
# 17556  https://cdn.sofifa.com/teams/113186/light_30.png  ...     59.0
# 17557     https://cdn.sofifa.com/teams/159/light_30.png  ...     54.0
# 17558  https://cdn.sofifa.com/teams/110233/light_30.png  ...     47.0
# 17559    https://cdn.sofifa.com/teams/1949/light_30.png  ...     46.0
#
#       GKHandling  GKKicking GKPositioning  GKReflexes  Best Position  \
# 0           25.0       31.0          33.0        37.0             ST
# 1           11.0       14.0           8.0        11.0            CDM
# 2            2.0        4.0           2.0         4.0            CDM
# 3            7.0       14.0          15.0         9.0             LB
# 4            6.0        2.0           4.0         3.0            CAM
# ...          ...        ...           ...         ...            ...
# 17555       51.0       48.0          59.0        60.0             GK
# 17556       46.0       41.0          62.0        59.0             GK
# 17557       50.0       49.0          54.0        58.0             GK
# 17558       59.0       52.0          44.0        49.0             GK
# 17559       47.0       54.0          43.0        48.0             GK
#
#        Best Overall Rating version Next_Overall         Next_Year_Club
# 0                     88.0    2017         92.0           FC Barcelona
# 1                     84.0    2017         86.0                   Roma
# 2                     85.0    2017         86.0      FC Bayern München
# 3                     84.0    2017         85.0      FC Bayern München
# 4                     85.0    2017         88.0      Manchester United
# ...                    ...     ...          ...                    ...
# 17555                 53.0    2017          NaN                    NaN
# 17556                 56.0    2017          NaN                    NaN
# 17557                 52.0    2017         60.0  DSC Arminia Bielefeld
# 17558                 49.0    2017          NaN                    NaN
# 17559                 45.0    2017         46.0      Scunthorpe United
#
# [17560 rows x 66 columns]

# %%
addNextGradeToDf(f_2018, f_2019)
addNextClubToDf(f_2018, f_2019)
# Out:
#            ID            Name  Age  \
# 0      176580       L. Suárez   30
# 1      178518   R. Nainggolan   29
# 2      203551     A. Florenzi   26
# 3      197445        D. Alaba   25
# 4      195864        P. Pogba   24
# ...       ...             ...  ...
# 17922  240757      A. Viscovo   18
# 17923  237463       A. Kelsey   17
# 17924  240790     A. Giacomel   18
# 17925  241206      D. Maekawa   22
# 17926  243202        A. Jones   16
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/18_60.png     Uruguay
# 1      https://cdn.sofifa.com/players/178/518/18_60.png     Belgium
# 2      https://cdn.sofifa.com/players/203/551/18_60.png       Italy
# 3      https://cdn.sofifa.com/players/197/445/18_60.png     Austria
# 4      https://cdn.sofifa.com/players/195/864/18_60.png      France
# ...                                                 ...         ...
# 17922  https://cdn.sofifa.com/players/240/757/18_60.png       Italy
# 17923  https://cdn.sofifa.com/players/237/463/18_60.png     England
# 17924  https://cdn.sofifa.com/players/240/790/18_60.png       Italy
# 17925  https://cdn.sofifa.com/players/241/206/18_60.png       Japan
# 17926  https://cdn.sofifa.com/players/243/202/18_60.png     England
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/uy.png       92         92
# 1          https://cdn.sofifa.com/flags/be.png       86         86
# 2          https://cdn.sofifa.com/flags/it.png       82         83
# 3          https://cdn.sofifa.com/flags/at.png       85         87
# 4          https://cdn.sofifa.com/flags/fr.png       88         92
# ...                                        ...      ...        ...
# 17922      https://cdn.sofifa.com/flags/it.png       51         70
# 17923  https://cdn.sofifa.com/flags/gb-eng.png       46         63
# 17924      https://cdn.sofifa.com/flags/it.png       49         64
# 17925      https://cdn.sofifa.com/flags/jp.png       54         61
# 17926  https://cdn.sofifa.com/flags/gb-eng.png       48         66
#
#                      Club                                         Club Logo  \
# 0            FC Barcelona     https://cdn.sofifa.com/teams/241/light_30.png
# 1                    Roma      https://cdn.sofifa.com/teams/52/light_30.png
# 2                    Roma      https://cdn.sofifa.com/teams/52/light_30.png
# 3       FC Bayern München      https://cdn.sofifa.com/teams/21/light_30.png
# 4       Manchester United      https://cdn.sofifa.com/teams/11/light_30.png
# ...                   ...                                               ...
# 17922             Crotone  https://cdn.sofifa.com/teams/110734/light_30.png
# 17923   Scunthorpe United    https://cdn.sofifa.com/teams/1949/light_30.png
# 17924              Empoli    https://cdn.sofifa.com/teams/1746/light_30.png
# 17925         Vissel Kobe  https://cdn.sofifa.com/teams/101146/light_30.png
# 17926  Milton Keynes Dons    https://cdn.sofifa.com/teams/1798/light_30.png
#
#        ... GKHandling GKKicking  GKPositioning GKReflexes  Best Position  \
# 0      ...       25.0      31.0           33.0       37.0             CF
# 1      ...       11.0      14.0            8.0       11.0            CDM
# 2      ...        8.0      10.0           11.0       10.0             CF
# 3      ...        7.0      14.0           15.0        9.0             LB
# 4      ...        6.0       2.0            4.0        3.0             CM
# ...    ...        ...       ...            ...        ...            ...
# 17922  ...       46.0      57.0           52.0       47.0             GK
# 17923  ...       47.0      49.0           42.0       48.0             GK
# 17924  ...       55.0      48.0           45.0       56.0             GK
# 17925  ...       51.0      44.0           55.0       59.0             GK
# 17926  ...       43.0      42.0           39.0       52.0             GK
#
#        Best Overall Rating  Release Clause version Next_Overall  \
# 0                     88.0         €198.9M    2018         91.0
# 1                     84.0          €72.3M    2018         85.0
# 2                     81.0          €37.3M    2018         82.0
# 3                     82.0          €66.4M    2018         84.0
# 4                     85.0         €146.3M    2018         88.0
# ...                    ...             ...     ...          ...
# 17922                 50.0           €146K    2018          NaN
# 17923                 45.0           €119K    2018          NaN
# 17924                 48.0           €111K    2018          NaN
# 17925                 53.0           €102K    2018         60.0
# 17926                 47.0           €119K    2018          NaN
#
#           Next_Year_Club
# 0           FC Barcelona
# 1                  Inter
# 2                   Roma
# 3      FC Bayern München
# 4      Manchester United
# ...                  ...
# 17922                NaN
# 17923                NaN
# 17924                NaN
# 17925        Vissel Kobe
# 17926                NaN
#
# [17927 rows x 67 columns]

# %%
addNextGradeToDf(f_2019, f_2020)
addNextClubToDf(f_2019, f_2020)
# Out:
#            ID            Name  Age  \
# 0      176580       L. Suárez   31
# 1      194765    A. Griezmann   27
# 2      177003       L. Modrić   32
# 3      224334        M. Acuña   26
# 4      192985    K. De Bruyne   27
# ...       ...             ...  ...
# 17938  233940   M. Brzozowski   19
# 17939  245370   E. Destanoglu   17
# 17940  233215        C. Addai   20
# 17941  246648    O. Battersby   16
# 17942  248182      H. Sveijer   16
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/19_60.png     Uruguay
# 1      https://cdn.sofifa.com/players/194/765/19_60.png      France
# 2      https://cdn.sofifa.com/players/177/003/19_60.png     Croatia
# 3      https://cdn.sofifa.com/players/224/334/19_60.png   Argentina
# 4      https://cdn.sofifa.com/players/192/985/19_60.png     Belgium
# ...                                                 ...         ...
# 17938  https://cdn.sofifa.com/players/233/940/19_60.png      Poland
# 17939  https://cdn.sofifa.com/players/245/370/19_60.png      Turkey
# 17940  https://cdn.sofifa.com/players/233/215/19_60.png       Ghana
# 17941  https://cdn.sofifa.com/players/246/648/19_60.png     England
# 17942  https://cdn.sofifa.com/players/248/182/19_60.png      Sweden
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/uy.png       91         91
# 1          https://cdn.sofifa.com/flags/fr.png       89         89
# 2          https://cdn.sofifa.com/flags/hr.png       91         91
# 3          https://cdn.sofifa.com/flags/ar.png       81         81
# 4          https://cdn.sofifa.com/flags/be.png       91         91
# ...                                        ...      ...        ...
# 17938      https://cdn.sofifa.com/flags/pl.png       49         60
# 17939      https://cdn.sofifa.com/flags/tr.png       50         68
# 17940      https://cdn.sofifa.com/flags/gh.png       51         61
# 17941  https://cdn.sofifa.com/flags/gb-eng.png       50         70
# 17942      https://cdn.sofifa.com/flags/se.png       48         63
#
#                       Club                                         Club Logo  \
# 0             FC Barcelona     https://cdn.sofifa.com/teams/241/light_30.png
# 1          Atlético Madrid     https://cdn.sofifa.com/teams/240/light_30.png
# 2              Real Madrid     https://cdn.sofifa.com/teams/243/light_30.png
# 3              Sporting CP     https://cdn.sofifa.com/teams/237/light_30.png
# 4          Manchester City      https://cdn.sofifa.com/teams/10/light_30.png
# ...                    ...                                               ...
# 17938  Queens Park Rangers      https://cdn.sofifa.com/teams/15/light_30.png
# 17939          Beşiktaş JK     https://cdn.sofifa.com/teams/327/light_30.png
# 17940        Coventry City    https://cdn.sofifa.com/teams/1800/light_30.png
# 17941         Grimsby Town      https://cdn.sofifa.com/teams/92/light_30.png
# 17942            IK Sirius  https://cdn.sofifa.com/teams/113458/light_30.png
#
#        ... GKHandling GKKicking  GKPositioning GKReflexes  Best Position  \
# 0      ...       25.0      31.0           33.0       37.0             ST
# 1      ...        8.0      14.0           13.0       14.0             LW
# 2      ...        9.0       7.0           14.0        9.0             CM
# 3      ...       14.0      13.0           13.0       14.0             LM
# 4      ...       13.0       5.0           10.0       13.0            CAM
# ...    ...        ...       ...            ...        ...            ...
# 17938  ...       52.0      52.0           44.0       51.0             GK
# 17939  ...       52.0      50.0           47.0       52.0             GK
# 17940  ...       48.0      40.0           54.0       56.0             GK
# 17941  ...       51.0      50.0           52.0       53.0             GK
# 17942  ...       49.0      48.0           47.0       51.0             GK
#
#        Best Overall Rating  Release Clause version Next_Overall  \
# 0                     87.0           €164M    2019         89.0
# 1                     87.0         €145.6M    2019         89.0
# 2                     88.0         €137.4M    2019         89.0
# 3                     81.0            €38M    2019         82.0
# 4                     89.0         €172.1M    2019         91.0
# ...                    ...             ...     ...          ...
# 17938                 48.0            €84K    2019          NaN
# 17939                 49.0           €126K    2019         62.0
# 17940                 50.0            €98K    2019          NaN
# 17941                 49.0           €138K    2019          NaN
# 17942                 47.0            €94K    2019         48.0
#
#         Next_Year_Club
# 0         FC Barcelona
# 1         FC Barcelona
# 2          Real Madrid
# 3          Sporting CP
# 4      Manchester City
# ...                ...
# 17938              NaN
# 17939      Beşiktaş JK
# 17940              NaN
# 17941              NaN
# 17942        IK Sirius
#
# [17943 rows x 67 columns]

# %%
addNextGradeToDf(f_2020, f_2021)
addNextClubToDf(f_2020, f_2021)
# Out:
#            ID              Name  Age  \
# 0      176580         L. Suárez   32
# 1      194765      A. Griezmann   28
# 2      212198   Bruno Fernandes   24
# 3      192985      K. De Bruyne   28
# 4      224334          M. Acuña   27
# ...       ...               ...  ...
# 17099  251433           B. Voll   18
# 17100  239426     18 N. Krucker   18
# 17101  240757     18 A. Viscovo   18
# 17102  248182        H. Sveijer   17
# 17103  178453     07 A. Censori   17
#
#                                                   Photo  Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/20_60.png      Uruguay
# 1      https://cdn.sofifa.com/players/194/765/20_60.png       France
# 2      https://cdn.sofifa.com/players/212/198/20_60.png     Portugal
# 3      https://cdn.sofifa.com/players/192/985/20_60.png      Belgium
# 4      https://cdn.sofifa.com/players/224/334/20_60.png    Argentina
# ...                                                 ...          ...
# 17099  https://cdn.sofifa.com/players/251/433/20_60.png      Germany
# 17100  https://cdn.sofifa.com/players/239/426/18_60.png  Switzerland
# 17101  https://cdn.sofifa.com/players/240/757/18_60.png        Italy
# 17102  https://cdn.sofifa.com/players/248/182/20_60.png       Sweden
# 17103  https://cdn.sofifa.com/players/178/453/07_60.png        Italy
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.com/flags/uy.png       89         89
# 1      https://cdn.sofifa.com/flags/fr.png       89         89
# 2      https://cdn.sofifa.com/flags/pt.png       86         89
# 3      https://cdn.sofifa.com/flags/be.png       91         91
# 4      https://cdn.sofifa.com/flags/ar.png       82         82
# ...                                    ...      ...        ...
# 17099  https://cdn.sofifa.com/flags/de.png       51         63
# 17100  https://cdn.sofifa.com/flags/ch.png       50         61
# 17101  https://cdn.sofifa.com/flags/it.png       51         70
# 17102  https://cdn.sofifa.com/flags/se.png       48         63
# 17103  https://cdn.sofifa.com/flags/it.png       28         38
#
#                     Club                                         Club Logo  \
# 0           FC Barcelona     https://cdn.sofifa.com/teams/241/light_30.png
# 1           FC Barcelona     https://cdn.sofifa.com/teams/241/light_30.png
# 2      Manchester United      https://cdn.sofifa.com/teams/11/light_30.png
# 3        Manchester City      https://cdn.sofifa.com/teams/10/light_30.png
# 4            Sporting CP     https://cdn.sofifa.com/teams/237/light_30.png
# ...                  ...                                               ...
# 17099   FC Hansa Rostock      https://cdn.sofifa.com/teams/27/light_30.png
# 17100      FC St. Gallen     https://cdn.sofifa.com/teams/898/light_30.png
# 17101            Crotone  https://cdn.sofifa.com/teams/110734/light_30.png
# 17102          IK Sirius  https://cdn.sofifa.com/teams/113458/light_30.png
# 17103             Arezzo  https://cdn.sofifa.com/teams/110907/light_30.png
#
#        ... GKKicking GKPositioning  GKReflexes Best Position  \
# 0      ...      31.0          33.0        37.0            ST
# 1      ...      14.0          13.0        14.0            CF
# 2      ...      15.0           8.0        14.0           CAM
# 3      ...       5.0          10.0        13.0           CAM
# 4      ...      13.0          13.0        14.0            LB
# ...    ...       ...           ...         ...           ...
# 17099  ...      52.0          42.0        57.0            GK
# 17100  ...      55.0          49.0        51.0            GK
# 17101  ...      57.0          52.0        47.0            GK
# 17102  ...      48.0          47.0        51.0            GK
# 17103  ...      36.0           6.0         9.0            ST
#
#        Best Overall Rating  Release Clause  DefensiveAwareness version  \
# 0                     89.0         €108.7M                57.0    2020
# 1                     89.0         €141.5M                59.0    2020
# 2                     87.0         €111.6M                72.0    2020
# 3                     91.0         €166.5M                68.0    2020
# 4                     82.0            €40M                79.0    2020
# ...                    ...             ...                 ...     ...
# 17099                 51.0            €83K                 5.0    2020
# 17100                 49.0            €66K                 NaN    2020
# 17101                 50.0           €146K                 NaN    2020
# 17102                 48.0            €94K                 8.0    2020
# 17103                 36.0             NaN                 NaN    2020
#
#       Next_Overall     Next_Year_Club
# 0             87.0    Atlético Madrid
# 1             87.0       FC Barcelona
# 2             87.0  Manchester United
# 3             91.0    Manchester City
# 4             83.0         Sevilla FC
# ...            ...                ...
# 17099         51.0   FC Hansa Rostock
# 17100          NaN                NaN
# 17101          NaN                NaN
# 17102         49.0          IK Sirius
# 17103          NaN                NaN
#
# [17104 rows x 68 columns]

# %%
addNextGradeToDf(f_2021, f_2022)
addNextClubToDf(f_2021, f_2022)
# Out:
#            ID              Name  Age  \
# 0      176580         L. Suárez   33
# 1      192985      K. De Bruyne   29
# 2      212198   Bruno Fernandes   25
# 3      194765      A. Griezmann   29
# 4      224334          M. Acuña   28
# ...       ...               ...  ...
# 17103  247866      19 C. Miszta   16
# 17104  251433           B. Voll   19
# 17105  252420         T. Parker   18
# 17106  248182        H. Sveijer   18
# 17107  245862       19 J. Milli   18
#
#                                                   Photo       Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/20_60.png           Uruguay
# 1      https://cdn.sofifa.com/players/192/985/20_60.png           Belgium
# 2      https://cdn.sofifa.com/players/212/198/20_60.png          Portugal
# 3      https://cdn.sofifa.com/players/194/765/20_60.png            France
# 4      https://cdn.sofifa.com/players/224/334/20_60.png         Argentina
# ...                                                 ...               ...
# 17103  https://cdn.sofifa.com/players/247/866/19_60.png            Poland
# 17104  https://cdn.sofifa.com/players/251/433/20_60.png           Germany
# 17105  https://cdn.sofifa.com/players/252/420/20_60.png  Northern Ireland
# 17106  https://cdn.sofifa.com/players/248/182/20_60.png            Sweden
# 17107  https://cdn.sofifa.com/players/245/862/19_60.png             Italy
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/uy.png       87         87
# 1          https://cdn.sofifa.com/flags/be.png       91         91
# 2          https://cdn.sofifa.com/flags/pt.png       87         90
# 3          https://cdn.sofifa.com/flags/fr.png       87         87
# 4          https://cdn.sofifa.com/flags/ar.png       83         83
# ...                                        ...      ...        ...
# 17103      https://cdn.sofifa.com/flags/pl.png       50         70
# 17104      https://cdn.sofifa.com/flags/de.png       51         63
# 17105  https://cdn.sofifa.com/flags/gb-nir.png       51         70
# 17106      https://cdn.sofifa.com/flags/se.png       49         63
# 17107      https://cdn.sofifa.com/flags/it.png       47         65
#
#                     Club                                         Club Logo  \
# 0        Atlético Madrid     https://cdn.sofifa.com/teams/240/light_30.png
# 1        Manchester City      https://cdn.sofifa.com/teams/10/light_30.png
# 2      Manchester United      https://cdn.sofifa.com/teams/11/light_30.png
# 3           FC Barcelona     https://cdn.sofifa.com/teams/241/light_30.png
# 4             Sevilla FC     https://cdn.sofifa.com/teams/481/light_30.png
# ...                  ...                                               ...
# 17103     Legia Warszawa    https://cdn.sofifa.com/teams/1871/light_30.png
# 17104   FC Hansa Rostock      https://cdn.sofifa.com/teams/27/light_30.png
# 17105         Luton Town    https://cdn.sofifa.com/teams/1923/light_30.png
# 17106          IK Sirius  https://cdn.sofifa.com/teams/113458/light_30.png
# 17107              Lecce     https://cdn.sofifa.com/teams/347/light_30.png
#
#        ... GKKicking GKPositioning  GKReflexes Best Position  \
# 0      ...      31.0          33.0        37.0            ST
# 1      ...       5.0          10.0        13.0           CAM
# 2      ...      15.0           8.0        14.0           CAM
# 3      ...      14.0          13.0        14.0            ST
# 4      ...      13.0          13.0        14.0            LB
# ...    ...       ...           ...         ...           ...
# 17103  ...      56.0          40.0        56.0            GK
# 17104  ...      52.0          42.0        57.0            GK
# 17105  ...      50.0          53.0        55.0            GK
# 17106  ...      49.0          50.0        51.0            GK
# 17107  ...      52.0          40.0        44.0            GK
#
#        Best Overall Rating  Release Clause  DefensiveAwareness version  \
# 0                     87.0          €64.6M                57.0    2021
# 1                     91.0           €161M                68.0    2021
# 2                     88.0         €124.4M                72.0    2021
# 3                     87.0         €103.5M                59.0    2021
# 4                     83.0          €46.2M                79.0    2021
# ...                    ...             ...                 ...     ...
# 17103                 49.0           €120K                 NaN    2021
# 17104                 51.0            €83K                 5.0    2021
# 17105                 51.0           €149K                 8.0    2021
# 17106                 49.0            €94K                 8.0    2021
# 17107                 46.0           €109K                 NaN    2021
#
#       Next_Overall      Next_Year_Club
# 0             88.0  Atlético de Madrid
# 1             91.0     Manchester City
# 2             88.0   Manchester United
# 3             85.0  Atlético de Madrid
# 4             84.0          Sevilla FC
# ...            ...                 ...
# 17103         59.0      Legia Warszawa
# 17104         58.0  F.C. Hansa Rostock
# 17105          NaN                 NaN
# 17106          NaN                 NaN
# 17107          NaN                 NaN
#
# [17108 rows x 68 columns]

# %%
addNextGradeToDf(f_2022, f_2023)
addNextClubToDf(f_2022, f_2023)
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16705  240558    18 L. Clayton   17
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
# 16709  178453    07 A. Censori   17
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# 16705  https://cdn.sofifa.com/players/240/558/18_60.png     England
# 16706  https://cdn.sofifa.com/players/262/846/22_60.png     Romania
# 16707  https://cdn.sofifa.com/players/241/317/21_60.png    China PR
# 16708  https://cdn.sofifa.com/players/259/646/22_60.png       India
# 16709  https://cdn.sofifa.com/players/178/453/07_60.png       Italy
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/pt.png       88         89
# 1          https://cdn.sofifa.com/flags/de.png       87         88
# 2          https://cdn.sofifa.com/flags/uy.png       88         88
# 3          https://cdn.sofifa.com/flags/be.png       91         91
# 4          https://cdn.sofifa.com/flags/ar.png       84         84
# ...                                        ...      ...        ...
# 16705  https://cdn.sofifa.com/flags/gb-eng.png       53         70
# 16706      https://cdn.sofifa.com/flags/ro.png       53         63
# 16707      https://cdn.sofifa.com/flags/cn.png       47         60
# 16708      https://cdn.sofifa.com/flags/in.png       47         67
# 16709      https://cdn.sofifa.com/flags/it.png       28         38
#
#                         Club                                   Club Logo  ...  \
# 0          Manchester United      https://cdn.sofifa.com/teams/11/30.png  ...
# 1          FC Bayern München      https://cdn.sofifa.com/teams/21/30.png  ...
# 2         Atlético de Madrid     https://cdn.sofifa.com/teams/240/30.png  ...
# 3            Manchester City      https://cdn.sofifa.com/teams/10/30.png  ...
# 4                 Sevilla FC     https://cdn.sofifa.com/teams/481/30.png  ...
# ...                      ...                                         ...  ...
# 16705        Cheltenham Town    https://cdn.sofifa.com/teams/1936/30.png  ...
# 16706  FC Academica Clinceni  https://cdn.sofifa.com/teams/113391/30.png  ...
# 16707    Shanghai Shenhua FC  https://cdn.sofifa.com/teams/110955/30.png  ...
# 16708     ATK Mohun Bagan FC  https://cdn.sofifa.com/teams/113146/30.png  ...
# 16709                 Arezzo  https://cdn.sofifa.com/teams/110907/30.png  ...
#
#       GKKicking GKPositioning  GKReflexes Best Position  Best Overall Rating  \
# 0          15.0           8.0        14.0           CAM                 88.0
# 1          15.0          11.0         9.0            CM                 87.0
# 2          31.0          33.0        37.0            ST                 88.0
# 3           5.0          10.0        13.0            CM                 91.0
# 4          13.0          13.0        14.0            LB                 84.0
# ...         ...           ...         ...           ...                  ...
# 16705      52.0          50.0        59.0            GK                 52.0
# 16706      53.0          48.0        58.0            GK                 53.0
# 16707      45.0          38.0        52.0            GK                 47.0
# 16708      39.0          45.0        49.0            GK                 47.0
# 16709      36.0           6.0         9.0            ST                 36.0
#
#        Release Clause  DefensiveAwareness version Next_Overall  \
# 0             €206.9M                72.0    2022         86.0
# 1             €160.4M                74.0    2022         87.0
# 2              €91.2M                42.0    2022         84.0
# 3             €232.2M                68.0    2022         91.0
# 4              €77.7M                80.0    2022         85.0
# ...               ...                 ...     ...          ...
# 16705           €238K                 NaN    2022          NaN
# 16706           €279K                 5.0    2022         55.0
# 16707           €223K                21.0    2022          NaN
# 16708           €259K                 7.0    2022          NaN
# 16709             NaN                 NaN    2022          NaN
#
#                   Next_Year_Club
# 0              Manchester United
# 1              FC Bayern München
# 2      Club Nacional de Football
# 3                Manchester City
# 4                     Sevilla FC
# ...                          ...
# 16705                        NaN
# 16706      FC Academica Clinceni
# 16707                        NaN
# 16708                        NaN
# 16709                        NaN
#
# [16710 rows x 68 columns]

# %% [markdown]
# ## Combine All Datasets To 1

# %%
df = pd.concat([f_2017 , f_2018 , f_2019 , f_2020 , f_2021, f_2022])

# %%
df
# Out:
#            ID            Name  Age  \
# 0      176580       L. Suárez   29
# 1      178518   R. Nainggolan   28
# 2      181872        A. Vidal   29
# 3      197445        D. Alaba   24
# 4      195864        P. Pogba   23
# ...       ...             ...  ...
# 16705  240558   18 L. Clayton   17
# 16706  262846        �. Dobre   20
# 16707  241317  21 Xue Qinghao   19
# 16708  259646       A. Shaikh   18
# 16709  178453   07 A. Censori   17
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1      https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2      https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3      https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4      https://cdn.sofifa.com/players/195/864/17_60.png      France
# ...                                                 ...         ...
# 16705  https://cdn.sofifa.com/players/240/558/18_60.png     England
# 16706  https://cdn.sofifa.com/players/262/846/22_60.png     Romania
# 16707  https://cdn.sofifa.com/players/241/317/21_60.png    China PR
# 16708  https://cdn.sofifa.com/players/259/646/22_60.png       India
# 16709  https://cdn.sofifa.com/players/178/453/07_60.png       Italy
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/uy.png       92         92
# 1          https://cdn.sofifa.com/flags/be.png       86         86
# 2          https://cdn.sofifa.com/flags/cl.png       87         87
# 3          https://cdn.sofifa.com/flags/at.png       86         89
# 4          https://cdn.sofifa.com/flags/fr.png       88         94
# ...                                        ...      ...        ...
# 16705  https://cdn.sofifa.com/flags/gb-eng.png       53         70
# 16706      https://cdn.sofifa.com/flags/ro.png       53         63
# 16707      https://cdn.sofifa.com/flags/cn.png       47         60
# 16708      https://cdn.sofifa.com/flags/in.png       47         67
# 16709      https://cdn.sofifa.com/flags/it.png       28         38
#
#                         Club                                      Club Logo  \
# 0               FC Barcelona  https://cdn.sofifa.com/teams/241/light_30.png
# 1                       Roma   https://cdn.sofifa.com/teams/52/light_30.png
# 2          FC Bayern München   https://cdn.sofifa.com/teams/21/light_30.png
# 3          FC Bayern München   https://cdn.sofifa.com/teams/21/light_30.png
# 4          Manchester United   https://cdn.sofifa.com/teams/11/light_30.png
# ...                      ...                                            ...
# 16705        Cheltenham Town       https://cdn.sofifa.com/teams/1936/30.png
# 16706  FC Academica Clinceni     https://cdn.sofifa.com/teams/113391/30.png
# 16707    Shanghai Shenhua FC     https://cdn.sofifa.com/teams/110955/30.png
# 16708     ATK Mohun Bagan FC     https://cdn.sofifa.com/teams/113146/30.png
# 16709                 Arezzo     https://cdn.sofifa.com/teams/110907/30.png
#
#        ... GKKicking GKPositioning  GKReflexes Best Position  \
# 0      ...      31.0          33.0        37.0            ST
# 1      ...      14.0           8.0        11.0           CDM
# 2      ...       4.0           2.0         4.0           CDM
# 3      ...      14.0          15.0         9.0            LB
# 4      ...       2.0           4.0         3.0           CAM
# ...    ...       ...           ...         ...           ...
# 16705  ...      52.0          50.0        59.0            GK
# 16706  ...      53.0          48.0        58.0            GK
# 16707  ...      45.0          38.0        52.0            GK
# 16708  ...      39.0          45.0        49.0            GK
# 16709  ...      36.0           6.0         9.0            ST
#
#        Best Overall Rating  version  Next_Overall         Next_Year_Club  \
# 0                     88.0     2017          92.0           FC Barcelona
# 1                     84.0     2017          86.0                   Roma
# 2                     85.0     2017          86.0      FC Bayern München
# 3                     84.0     2017          85.0      FC Bayern München
# 4                     85.0     2017          88.0      Manchester United
# ...                    ...      ...           ...                    ...
# 16705                 52.0     2022           NaN                    NaN
# 16706                 53.0     2022          55.0  FC Academica Clinceni
# 16707                 47.0     2022           NaN                    NaN
# 16708                 47.0     2022           NaN                    NaN
# 16709                 36.0     2022           NaN                    NaN
#
#       Release Clause DefensiveAwareness
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# ...              ...                ...
# 16705          €238K                NaN
# 16706          €279K                5.0
# 16707          €223K               21.0
# 16708          €259K                7.0
# 16709            NaN                NaN
#
# [104352 rows x 68 columns]

# %% [markdown]
# ## Drop Unused Columns

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating', 'version', 'Next_Overall',
#        'Next_Year_Club', 'Release Clause', 'DefensiveAwareness'],
#       dtype='object')

# %%
df =df.drop([ 'Best Overall Rating' ,
             'Release Clause', 'Loaned From', 'Contract Valid Until', 'Jersey Number', 'Joined'
             , 'Nationality', 'Real Face', 'Photo', 'Flag', 'Club Logo', 'Preferred Foot',
            'Real Face', 'Special' , 'Body Type', "Marking" ], axis=1)

# %%
df
# Out:
#            ID            Name  Age  Overall  Potential                   Club  \
# 0      176580       L. Suárez   29       92         92           FC Barcelona
# 1      178518   R. Nainggolan   28       86         86                   Roma
# 2      181872        A. Vidal   29       87         87      FC Bayern München
# 3      197445        D. Alaba   24       86         89      FC Bayern München
# 4      195864        P. Pogba   23       88         94      Manchester United
# ...       ...             ...  ...      ...        ...                    ...
# 16705  240558   18 L. Clayton   17       53         70        Cheltenham Town
# 16706  262846        �. Dobre   20       53         63  FC Academica Clinceni
# 16707  241317  21 Xue Qinghao   19       47         60    Shanghai Shenhua FC
# 16708  259646       A. Shaikh   18       47         67     ATK Mohun Bagan FC
# 16709  178453   07 A. Censori   17       28         38                 Arezzo
#
#         Value   Wage  International Reputation  Weak Foot  ...  GKDiving  \
# 0        €83M  €525K                       5.0        4.0  ...      27.0
# 1      €37.5M  €130K                       3.0        3.0  ...      11.0
# 2      €41.5M  €180K                       4.0        4.0  ...       4.0
# 3      €41.5M  €140K                       4.0        4.0  ...       5.0
# 4      €71.5M  €225K                       4.0        4.0  ...       5.0
# ...       ...    ...                       ...        ...  ...       ...
# 16705   €100K    €1K                       1.0        2.0  ...      55.0
# 16706   €180K   €550                       1.0        2.0  ...      57.0
# 16707   €100K   €700                       1.0        2.0  ...      49.0
# 16708   €110K   €500                       1.0        3.0  ...      49.0
# 16709      €0     €0                       1.0        2.0  ...       7.0
#
#       GKHandling GKKicking GKPositioning GKReflexes  Best Position  version  \
# 0           25.0      31.0          33.0       37.0             ST     2017
# 1           11.0      14.0           8.0       11.0            CDM     2017
# 2            2.0       4.0           2.0        4.0            CDM     2017
# 3            7.0      14.0          15.0        9.0             LB     2017
# 4            6.0       2.0           4.0        3.0            CAM     2017
# ...          ...       ...           ...        ...            ...      ...
# 16705       54.0      52.0          50.0       59.0             GK     2022
# 16706       52.0      53.0          48.0       58.0             GK     2022
# 16707       48.0      45.0          38.0       52.0             GK     2022
# 16708       41.0      39.0          45.0       49.0             GK     2022
# 16709        1.0      36.0           6.0        9.0             ST     2022
#
#        Next_Overall         Next_Year_Club  DefensiveAwareness
# 0              92.0           FC Barcelona                 NaN
# 1              86.0                   Roma                 NaN
# 2              86.0      FC Bayern München                 NaN
# 3              85.0      FC Bayern München                 NaN
# 4              88.0      Manchester United                 NaN
# ...             ...                    ...                 ...
# 16705           NaN                    NaN                 NaN
# 16706          55.0  FC Academica Clinceni                 5.0
# 16707           NaN                    NaN                21.0
# 16708           NaN                    NaN                 7.0
# 16709           NaN                    NaN                 NaN
#
# [104352 rows x 53 columns]

# %% [markdown]
# ## Convert Wage to int

# %%
def convert_wage_to_int(df, column_name):
    for index, row in df.iterrows():
        wage = row[column_name]
        wage = wage.replace('€', '') # Remove euro symbol
        if wage[-1] == "M":
            df.at[index, column_name] = int(float(wage[0:-1]) * 1000000)
        elif wage[-1] == "K":
            df.at[index, column_name] = int(float(wage[0:-1]) * 1000)
        else:
            df.at[index, column_name] = int(float(wage))
    return df

# %%
df = convert_wage_to_int(df , "Wage")
df = convert_wage_to_int(df , "Value")

# %%
nan_cols = df.isna().any()

# print list of columns with NaN values
print(nan_cols[nan_cols == True].index.tolist())
# Out:
# ['Club', 'Position', 'Volleys', 'Curve', 'Agility', 'Balance', 'Jumping', 'Interceptions', 'Positioning', 'Vision', 'Composure', 'Marking', 'SlidingTackle', 'Next_Overall', 'Next_Year_Club']

# %% [markdown]
# #### Handling Missing Values

# %%
fifa_rating_categories = {
    'Pace': ['SprintSpeed', 'Acceleration'],
    'Shooting': ['Positioning', 'Finishing', 'ShotPower', 'LongShots', 'Volleys', 'Penalties'],
    'Passing': ['Vision', 'Crossing', 'FKAccuracy', 'ShortPassing', 'LongPassing', 'Curve'],
    'Dribbling': ['Agility', 'Balance', 'Reactions', 'BallControl', 'Dribbling', 'Composure'],
    'Defending': ['Interceptions', 'HeadingAccuracy', 'StandingTackle', 'SlidingTackle' , 'DefensiveAwareness'],
    'Physicality': ['Jumping', 'Stamina', 'Strength', 'Aggression']
}

# %%
# Dropping Unknown Players For Next Fifa
df = df.dropna(subset=['Next_Overall'])

# %%
def drop_rows_with_missing_ratings(df, fifa_rating_categories):
    """
    Drops rows with 2 or more missing sub-ratings in a given FIFA rating category.

    Args:
        df (pandas.DataFrame): The FIFA dataframe.
        fifa_rating_categories (dict): A dictionary mapping each FIFA rating category
            to its sub-ratings.

    Returns:
        pandas.DataFrame: The cleaned FIFA dataframe.
    """
    for i, row in df.iterrows():
        # Check each rating category
        for category, sub_ratings in fifa_rating_categories.items():
            missing_sub_ratings = 0
            for sub in sub_ratings:
                # Count the number of missing sub-ratings
                missing_sub_ratings = missing_sub_ratings +1
                # If there are 2 or more missing sub-ratings, drop the row
                if missing_sub_ratings >= 2:
                    df.drop(i)
                    break  # Move on to the next row
    return df

# %%
def drop_rows_with_nans(df, columns_dict):
    for cols in columns_dict.values():
#         print (cols)
        nan_counts = df[cols].isna().sum(axis=1)
        drop_rows = df[nan_counts >= 2].index
        df.drop(drop_rows, inplace=True)
    return df

# %%
def impute_missing_category_average(df, category_dict):
    for category, cols in category_dict.items():
        for col in cols:
            category_avg = df.groupby(category)[col].transform('mean')
            df[col] = df[col].fillna(category_avg)
    return df

# %%
df2 = drop_rows_with_nans(df.copy(), fifa_rating_categories)
df2
# Out:
#            ID             Name  Age  Overall  Potential  \
# 0      176580        L. Suárez   29       92         92
# 1      178518    R. Nainggolan   28       86         86
# 2      181872         A. Vidal   29       87         87
# 3      197445         D. Alaba   24       86         89
# 4      195864         P. Pogba   23       88         94
# ...       ...              ...  ...      ...        ...
# 16698  254562          A. Abaz   19       50         70
# 16699  262373  F. Chalupniczak   20       51         63
# 16701  263373        J. Searle   20       51         64
# 16703  259718      F. Gebhardt   19       52         66
# 16706  262846         �. Dobre   20       53         63
#
#                         Club   Value   Wage  International Reputation  \
# 0               FC Barcelona    €83M  €525K                       5.0
# 1                       Roma  €37.5M  €130K                       3.0
# 2          FC Bayern München  €41.5M  €180K                       4.0
# 3          FC Bayern München  €41.5M  €140K                       4.0
# 4          Manchester United  €71.5M  €225K                       4.0
# ...                      ...     ...    ...                       ...
# 16698     FC St. Gallen 1879   €120K   €500                       1.0
# 16699          Sutton United   €120K   €800                       1.0
# 16701           Swansea City   €120K    €2K                       1.0
# 16703          FC Basel 1893   €170K   €650                       1.0
# 16706  FC Academica Clinceni   €180K   €550                       1.0
#
#        Weak Foot  ...  GKDiving GKHandling GKKicking GKPositioning GKReflexes  \
# 0            4.0  ...      27.0       25.0      31.0          33.0       37.0
# 1            3.0  ...      11.0       11.0      14.0           8.0       11.0
# 2            4.0  ...       4.0        2.0       4.0           2.0        4.0
# 3            4.0  ...       5.0        7.0      14.0          15.0        9.0
# 4            4.0  ...       5.0        6.0       2.0           4.0        3.0
# ...          ...  ...       ...        ...       ...           ...        ...
# 16698        2.0  ...      49.0       53.0      50.0          48.0       50.0
# 16699        2.0  ...      50.0       52.0      51.0          51.0       52.0
# 16701        3.0  ...      51.0       53.0      52.0          49.0       50.0
# 16703        3.0  ...      53.0       45.0      47.0          52.0       57.0
# 16706        2.0  ...      57.0       52.0      53.0          48.0       58.0
#
#        Best Position  version  Next_Overall         Next_Year_Club  \
# 0                 ST     2017          92.0           FC Barcelona
# 1                CDM     2017          86.0                   Roma
# 2                CDM     2017          86.0      FC Bayern München
# 3                 LB     2017          85.0      FC Bayern München
# 4                CAM     2017          88.0      Manchester United
# ...              ...      ...           ...                    ...
# 16698             GK     2022          50.0          FC Winterthur
# 16699             GK     2022          51.0          Sutton United
# 16701             GK     2022          51.0               Barnsley
# 16703             GK     2022          58.0          Hallescher FC
# 16706             GK     2022          55.0  FC Academica Clinceni
#
#        DefensiveAwareness
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 16698                 7.0
# 16699                 9.0
# 16701                 7.0
# 16703                 6.0
# 16706                 5.0
#
# [68482 rows x 53 columns]

# %%
import math
def impute_with_overall(df, categories_dict):
    for category in categories_dict.values():
        df[category] = df[category].fillna(df['Overall'])
    return df

def impute_nans_with_overall(df, categories_dict):
    """
    Imputes every NaN value in the categories_dict values with that row's "overall" value.

    Args:
    df (pandas.DataFrame): The dataframe to impute the missing values in.
    categories_dict (dict): The dictionary containing lists of column names to impute.

    Returns:
    pandas.DataFrame: The dataframe with the missing values imputed.
    """
    for category, columns in categories_dict.items():
        category_cols = [col for col in df.columns if col in columns]
        for col in category_cols:
#             df[col].fillna(df["Overall"], inplace=True)
            category_cols_without_col = [c for c in category_cols if c != col]
            df[col] = df.apply(lambda x: math.floor((x[col] if not pd.isna(x[col]) else (x[category_cols_without_col].mean()))), axis=1)
#             df[col].fillna(df[[x for x in category_cols if x != col]].mean(), inplace=True)
    return df

# %%
df3 = impute_nans_with_overall(df2.copy(), fifa_rating_categories)
df3
# Out:
#            ID             Name  Age  Overall  Potential  \
# 0      176580        L. Suárez   29       92         92
# 1      178518    R. Nainggolan   28       86         86
# 2      181872         A. Vidal   29       87         87
# 3      197445         D. Alaba   24       86         89
# 4      195864         P. Pogba   23       88         94
# ...       ...              ...  ...      ...        ...
# 16698  254562          A. Abaz   19       50         70
# 16699  262373  F. Chalupniczak   20       51         63
# 16701  263373        J. Searle   20       51         64
# 16703  259718      F. Gebhardt   19       52         66
# 16706  262846         �. Dobre   20       53         63
#
#                         Club   Value   Wage  International Reputation  \
# 0               FC Barcelona    €83M  €525K                       5.0
# 1                       Roma  €37.5M  €130K                       3.0
# 2          FC Bayern München  €41.5M  €180K                       4.0
# 3          FC Bayern München  €41.5M  €140K                       4.0
# 4          Manchester United  €71.5M  €225K                       4.0
# ...                      ...     ...    ...                       ...
# 16698     FC St. Gallen 1879   €120K   €500                       1.0
# 16699          Sutton United   €120K   €800                       1.0
# 16701           Swansea City   €120K    €2K                       1.0
# 16703          FC Basel 1893   €170K   €650                       1.0
# 16706  FC Academica Clinceni   €180K   €550                       1.0
#
#        Weak Foot  ...  GKDiving GKHandling GKKicking GKPositioning GKReflexes  \
# 0            4.0  ...      27.0       25.0      31.0          33.0       37.0
# 1            3.0  ...      11.0       11.0      14.0           8.0       11.0
# 2            4.0  ...       4.0        2.0       4.0           2.0        4.0
# 3            4.0  ...       5.0        7.0      14.0          15.0        9.0
# 4            4.0  ...       5.0        6.0       2.0           4.0        3.0
# ...          ...  ...       ...        ...       ...           ...        ...
# 16698        2.0  ...      49.0       53.0      50.0          48.0       50.0
# 16699        2.0  ...      50.0       52.0      51.0          51.0       52.0
# 16701        3.0  ...      51.0       53.0      52.0          49.0       50.0
# 16703        3.0  ...      53.0       45.0      47.0          52.0       57.0
# 16706        2.0  ...      57.0       52.0      53.0          48.0       58.0
#
#        Best Position  version  Next_Overall         Next_Year_Club  \
# 0                 ST     2017          92.0           FC Barcelona
# 1                CDM     2017          86.0                   Roma
# 2                CDM     2017          86.0      FC Bayern München
# 3                 LB     2017          85.0      FC Bayern München
# 4                CAM     2017          88.0      Manchester United
# ...              ...      ...           ...                    ...
# 16698             GK     2022          50.0          FC Winterthur
# 16699             GK     2022          51.0          Sutton United
# 16701             GK     2022          51.0               Barnsley
# 16703             GK     2022          58.0          Hallescher FC
# 16706             GK     2022          55.0  FC Academica Clinceni
#
#        DefensiveAwareness
# 0                      50
# 1                      79
# 2                      85
# 3                      81
# 4                      72
# ...                   ...
# 16698                   7
# 16699                   9
# 16701                   7
# 16703                   6
# 16706                   5
#
# [68482 rows x 53 columns]

# %%
nan_cols = df3.isna().any()

# print list of columns with NaN values
print(nan_cols[nan_cols == True].index.tolist())
# Out:
# ['Club', 'Position', 'Next_Year_Club']

# %%
df = convert_wage_to_int(df3 , "Wage")
df = convert_wage_to_int(df , "Value")

# %% [markdown]
# ## Split to Positions

# %%
map_position= {
    'GK': 'Goalkeeper',
    'CB': 'Defender',
    'RB': 'Defender',
    'LB': 'Defender',
    'RWB': 'Defender',
    'LWB': 'Defender',
    'CM': 'Midfielder',
    'CDM': 'Midfielder',
    'CAM': 'Midfielder',
    'RM': 'Midfielder',
    'LM': 'Midfielder',
    'ST': 'Forward',
    'CF': 'Forward',
    'RF': 'Forward',
    'LF': 'Forward',
    'RW': 'Forward',
    'LW': 'Forward'
}

# %%
df['Position'] = df['Best Position'].map(map_position)

# %%
df['Position'] = df['Best Position'].map(map_position)
position_groups = df.groupby('Position')

# %%
type(position_groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
positions = {}
for position, group in position_groups:
    positions[str(position)] = pd.DataFrame(group)

# %%
positions.keys()
# Out:
# dict_keys(['Defender', 'Forward', 'Goalkeeper', 'Midfielder'])

# %%
defenders_df = positions['Defender']
forward_df = positions['Forward']
gk_df = positions['Goalkeeper']
midfielders_df = positions['Midfielder']

# %%
defenders_df
# Out:
#            ID            Name  Age  Overall  Potential      Value    Wage  \
# 3      197445        D. Alaba   24       86         89  107500000  350000
# 6      203551     A. Florenzi   25       82         85   55500000  220000
# 7      163631       L. Baines   31       83         83   28500000   61000
# 12     189332      Jordi Alba   27       86         86   77500000   90000
# 13     146530      Dani Alves   33       84         84   47000000   49000
# ...       ...             ...  ...      ...        ...        ...     ...
# 15794  164945  07 Nuno Mendes   28       71         70      70000     950
# 15799  252561        Zhang Yu   18       50         69      40000    1000
# 15817  262041      P. Maguire   18       49         67     110000     500
# 15869  239427     21 A. Ajeti   23       54         61    1600000    5000
# 15999  220806    16 E. Redman   18       44         57     525000     500
#
#        International Reputation  Weak Foot  Skill Moves  ... StandingTackle  \
# 3                           4.0        4.0          3.0  ...           83.0
# 6                           3.0        3.0          3.0  ...           79.0
# 7                           3.0        3.0          3.0  ...           82.0
# 12                          3.0        3.0          3.0  ...           84.0
# 13                          4.0        3.0          3.0  ...           80.0
# ...                         ...        ...          ...  ...            ...
# 15794                       2.0        3.0          1.0  ...           64.0
# 15799                       1.0        2.0          2.0  ...           53.0
# 15817                       1.0        3.0          2.0  ...           53.0
# 15869                       1.0        3.0          2.0  ...           57.0
# 15999                       1.0        2.0          2.0  ...           43.0
#
#       SlidingTackle GKDiving GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 3              83.0      5.0        7.0       14.0           15.0         9.0
# 6              77.0      9.0        8.0       10.0           11.0        10.0
# 7              82.0      8.0       15.0       10.0           13.0        12.0
# 12             83.0     13.0       15.0       13.0            6.0        13.0
# 13             84.0      5.0       11.0        9.0            6.0         7.0
# ...             ...      ...        ...        ...            ...         ...
# 15794           NaN     11.0       12.0       26.0           13.0        13.0
# 15799          50.0      5.0       13.0       12.0            5.0        15.0
# 15817          54.0     13.0        5.0       15.0            7.0         6.0
# 15869          59.0     14.0       13.0       10.0            9.0        10.0
# 15999          38.0     13.0        7.0       16.0            9.0         7.0
#
#        Best Position  version  Next_Overall
# 3                 LB     2017          85.0
# 6                 RB     2017          82.0
# 7                LWB     2017          80.0
# 12               LWB     2017          87.0
# 13               RWB     2017          83.0
# ...              ...      ...           ...
# 15794             CB     2022          71.0
# 15799             CB     2022           NaN
# 15817             CB     2022          49.0
# 15869             CB     2022           NaN
# 15999             CB     2022           NaN
#
# [34283 rows x 51 columns]

# %% [markdown]
# ## FIFA23 Prep

# %%
f_2023 = pd.read_csv(path_to_raw+"/Fifa 23 Players Data.csv" ,low_memory = False)

# %%
f_2023
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  LM Rating  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...         86
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...         91
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...         92
# ...                                                 ...  ...  ...        ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...         50
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...         45
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...         52
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...         33
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...         44
#
#        CM Rating  RM Rating  LWB Rating CDM Rating  RWB Rating  LB Rating  \
# 0             88         91          67         66          67         62
# 1             84         89          67         67          67         63
# 2             83         86          67         69          67         64
# 3             91         91          82         82          82         78
# 4             84         92          70         66          70         66
# ...          ...        ...         ...        ...         ...        ...
# 18534         44         50          41         38          41         40
# 18535         45         45          47         48          47         49
# 18536         49         52          46         44          46         46
# 18537         33         33          44         42          44         47
# 18538         40         44          46         43          46         47
#
#       CB Rating RB Rating GK Rating
# 0            53        62        22
# 1            58        63        21
# 2            63        64        22
# 3            72        78        24
# 4            57        66        21
# ...         ...       ...       ...
# 18534        36        40        15
# 18535        49        49        15
# 18536        42        46        17
# 18537        49        47        15
# 18538        47        47        19
#
# [18539 rows x 89 columns]

# %%
f_2023['Position'] = f_2023['Best Position'].map(map_position)

# %%
f_2023["Wage"] = f_2023["Wage(in Euro)"]
f_2023["Value"]= f_2023["Value(in Euro)"]

# %%
position_groups = f_2023.groupby('Position')

# %%
positions = {}
for position, group in position_groups:
    positions[str(position)] = pd.DataFrame(group)

# %%
defenders_df = positions['Defender']
forward_df = positions['Forward']
gk_df = positions['Goalkeeper']
midfielders_df = positions['Midfielder']

# %%
f_2023.to_csv(output_folder+'/predict-by-rating/f23-full.csv',mode='w',header=True, index=True)

# %%
defenders_df.to_csv(output_folder+'/predict-by-rating/f23-defenders_df.csv',mode='w',header=True, index=True)
gk_df.to_csv(output_folder+'/predict-by-rating/f23-gk_df.csv',mode='w',header=True, index=True)
midfielders_df.to_csv(output_folder+'/predict-by-rating/f23-midfielders_df.csv',mode='w',header=True, index=True)
forward_df.to_csv(output_folder+'/predict-by-rating/f23-forward_df.csv',mode='w',header=True, index=True)

# %%
f_2023.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'Standing Tackle', 'Sliding Tackle',
#        'Goalkeeper Diving', 'Goalkeeper Handling', ' GoalkeeperKicking',
#        'Goalkeeper Positioning', 'Goalkeeper Reflexes', 'ST Rating',
#        'LW Rating', 'LF Rating', 'CF Rating', 'RF Rating', 'RW Rating',
#        'CAM Rating', 'LM Rating', 'CM Rating', 'RM Rating', 'LWB Rating',
#        'CDM Rating', 'RWB Rating', 'LB Rating', 'CB Rating', 'RB Rating',
#        'GK Rating'],
#       dtype='object')

# %%
f_2022.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating', 'Release Clause',
#        'DefensiveAwareness'],
#       dtype='object')

# %% [markdown]
# # Export

# %%
df.to_csv(output_folder+'/predict-by-rating/Combined_Data.csv',mode='w',header=True, index=True)

# %%
defenders_df.to_csv(output_folder+'/predict-by-rating/defenders_df.csv',mode='w',header=True, index=True)
gk_df.to_csv(output_folder+'/predict-by-rating/gk_df.csv',mode='w',header=True, index=True)
midfielders_df.to_csv(output_folder+'/predict-by-rating/midfielders_df.csv',mode='w',header=True, index=True)
forward_df.to_csv(output_folder+'/predict-by-rating/forward_df.csv',mode='w',header=True, index=True)
